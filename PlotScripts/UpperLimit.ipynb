# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import pickle as pkl
import os, sys
import numpy as np
import matplotlib.pyplot as plt

# %%
channels = ["WW","bb","tautau","mumu","nuenue","numunumu","nutaunutau"]
ch_title = {"WW":r"$W^+ W^-$","bb":r"$b\bar{b}$","tautau":r"$\tau \bar{\tau}$", "mumu":r"$\mu^+\mu^-$","nuenue":r"$\nu_e \bar{\nu}_e$","numunumu":r'$\nu_\mu \bar{\nu}_\mu$',"nutaunutau":r"$\nu_\tau \bar{\nu}_\tau$"}
cols = {"WW":"purple","bb":"cyan","tautau":'dodgerblue', "mumu":"green","nuenue":"hotpink","numunumu":'deeppink',"nutaunutau":"pink"}
# channels = ["bb"]

profile = ['NFW', 'Burkert']
filepath = '/data/user/tchau/Sandbox/GC_OscNext/Sensitivity/UpperLimit/'
file = os.listdir(filepath)

# %%
profile = 'NFW'
for ch in channels:
    path = [file[i] for i in range(len(file)) if (ch +"_"+ profile in file[i])]
    if len(path)==0: continue
    UL = pkl.load(open(filepath+path[0], "rb"))
    if ch=='bb':
        plt.plot(UL['mass'][1:-1], UL['UL'][1:-1], marker='o', label=ch_title[ch], color=cols[ch])
    else:    
        plt.plot(UL['mass'], UL['UL'], marker='o',label=ch_title[ch], color=cols[ch])        

plt.semilogy()
plt.semilogx()
plt.ylim(1e-25, 6e-22)
plt.legend(ncol=4)
plt.ylabel(r'$\langle \sigma v \rangle$'+r' $[cm^3 s^{-1}]$')
plt.xlabel(r'$m_{\lambda}$'+' [GeV]')
plt.grid()
plt.title('{}'.format(profile))
# Out:
# Text(0.5, 1.0, 'NFW')

# %%
UL
# Out:
# {'mass': array([  5.        ,   5.67823618,   6.44847322,   7.32319078,
#           8.31656136,   9.44467992,  10.72582464,  12.1807531 ,
#          13.83303858,  15.70945202,  17.84039575,  20.26039611,
#          23.00866283,  26.12972434,  29.6741492 ,  33.6993655 ,
#          38.27059127,  43.46189117,  49.35737655,  56.05256822,
#          63.65594413,  72.29069696,  82.09673015,  93.23292462,
#         105.87971309, 120.24200345, 136.55249878, 155.07546772,
#         176.11102619, 200.        ]),
#  'UL': array([1.54123611e-24, 1.18856187e-24, 9.91606110e-25, 8.21245297e-25,
#         6.25797522e-25, 5.29297178e-25, 4.64390265e-25, 4.09633603e-25,
#         3.67465280e-25, 3.24669792e-25, 3.03326670e-25, 2.94053300e-25,
#         2.80365998e-25, 2.56652233e-25, 2.57295684e-25, 2.64345806e-25,
#         2.58249493e-25, 2.62626480e-25, 2.64948215e-25, 2.51963334e-25,
#         2.65223429e-25, 2.90442881e-25, 2.34987690e-25, 2.75174070e-25,
#         3.09529451e-25, 2.66136673e-25, 3.19604675e-25, 2.89935282e-25,
#         2.83656578e-25, 2.62357152e-25])}
