# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import pickle as pkl
import os, sys
import numpy as np
import matplotlib.pyplot as plt

# %%
channels = ["WW","bb","tautau","mumu","nuenue","numunumu","nutaunutau"]
ch_title = {"WW":r"$W^+ W^-$","bb":r"$b\bar{b}$","tautau":r"$\tau \bar{\tau}$", "mumu":r"$\mu^+\mu^-$","nuenue":r"$\nu_e \bar{\nu}_e$","numunumu":r'$\nu_\mu \bar{\nu}_\mu$',"nutaunutau":r"$\nu_\tau \bar{\nu}_\tau$"}
cols = {"WW":"purple","bb":"cyan","tautau":'dodgerblue', "mumu":"green","nuenue":"hotpink","numunumu":'deeppink',"nutaunutau":"pink"}
# channels = ["bb"]

profile = ['NFW', 'Burkert']
filepath = '/data/user/tchau/Sandbox/GC_OscNext/Sensitivity/UpperLimit/'
file = os.listdir(filepath)

# %%
profile = 'NFW'
for ch in channels:
    path = [file[i] for i in range(len(file)) if (ch +"_"+ profile in file[i] and 'testv1' in file[i])]
    if len(path)==0: continue
    print(path[0])
    UL = pkl.load(open(filepath+path[0], "rb"))
    # if ch=='bb':
    #     plt.plot(UL['mass'][1:-1], UL['UL'][1:-1], marker='o', label=ch_title[ch], color=cols[ch])
    # else:    
    plt.plot(UL['mass'], UL['UL'], marker='o',label=ch_title[ch], color=cols[ch])        

# UL = pkl.load(open('/data/user/tchau/Sandbox/GC_OscNext/Sensitivity/UpperLimit/WW_NFW_10_testv1.pkl', "rb"))
# plt.plot(UL['mass'], UL['UL'], marker='o',label='WW-new', color='gray')    

plt.semilogy()
plt.semilogx()
plt.ylim(1e-25, 6e-22)
plt.legend(ncol=4)
plt.ylabel(r'$\langle \sigma v \rangle$'+r' $[cm^3 s^{-1}]$')
plt.xlabel(r'$m_{\lambda}$'+' [GeV]')
plt.grid()
plt.title('{}'.format(profile))
# Out:
# WW_NFW_10_testv1.pkl
# bb_NFW_10_testv1.pkl
# tautau_NFW_10_testv1.pkl
# mumu_NFW_10_testv1.pkl
# nuenue_NFW_10_testv1.pkl
# numunumu_NFW_10_testv1.pkl
# nutaunutau_NFW_10_testv1.pkl
# Text(0.5, 1.0, 'NFW')

# %%
profile = 'NFW'
for ch in channels:
    path = [file[i] for i in range(len(file)) if (ch +"_"+ profile in file[i] and '30points_MC1122_BKGFFT' in file[i])]
    if len(path)==0: continue
    print(path[0])
    UL = pkl.load(open(filepath+path[0], "rb"))
    if ch=='bb':
        plt.plot(UL['mass'][1:-1], UL['UL'][1:-1], marker='o', label=ch_title[ch], color=cols[ch])
    else:    
        plt.plot(UL['mass'], UL['UL'], marker='o',label=ch_title[ch], color=cols[ch])        

# UL = pkl.load(open('/data/user/tchau/Sandbox/GC_OscNext/Sensitivity/UpperLimit/WW_NFW_10_testv1.pkl', "rb"))
# plt.plot(UL['mass'], UL['UL'], marker='o',label='WW-new', color='gray')    

plt.semilogy()
plt.semilogx()
plt.ylim(1e-25, 6e-22)
plt.legend(ncol=4)
plt.ylabel(r'$\langle \sigma v \rangle$'+r' $[cm^3 s^{-1}]$')
plt.xlabel(r'$m_{\lambda}$'+' [GeV]')
plt.grid()
plt.title('{}'.format(profile))
# Out:
# WW_NFW_30points_MC1122_BKGFFT.pkl
# bb_NFW_30points_MC1122_BKGFFT.pkl
# tautau_NFW_30points_MC1122_BKGFFT.pkl
# mumu_NFW_30points_MC1122_BKGFFT.pkl
# nuenue_NFW_30points_MC1122_BKGFFT.pkl
# numunumu_NFW_30points_MC1122_BKGFFT.pkl
# nutaunutau_NFW_30points_MC1122_BKGFFT.pkl
# Text(0.5, 1.0, 'NFW')

# %%
profile = 'NFW'
for ch in channels:
    path = [file[i] for i in range(len(file)) if (ch +"_"+ profile in file[i] and '30points_MC1122_BKGsklearn' in file[i])]
    if len(path)==0: continue
    print(path[0])
    UL = pkl.load(open(filepath+path[0], "rb"))
    if ch=='bb':
        plt.plot(UL['mass'][1:-1], UL['UL'][1:-1], marker='o', label=ch_title[ch], color=cols[ch])
    else:    
        plt.plot(UL['mass'], UL['UL'], marker='o',label=ch_title[ch], color=cols[ch])        

# UL = pkl.load(open('/data/user/tchau/Sandbox/GC_OscNext/Sensitivity/UpperLimit/WW_NFW_10_testv1.pkl', "rb"))
# plt.plot(UL['mass'], UL['UL'], marker='o',label='WW-new', color='gray')    

plt.semilogy()
plt.semilogx()
plt.ylim(1e-25, 6e-22)
plt.legend(ncol=4)
plt.ylabel(r'$\langle \sigma v \rangle$'+r' $[cm^3 s^{-1}]$')
plt.xlabel(r'$m_{\lambda}$'+' [GeV]')
plt.grid()
plt.title('{}'.format(profile))
# Out:
# WW_NFW_30points_MC1122_BKGsklearn.pkl
# bb_NFW_30points_MC1122_BKGsklearn.pkl
# tautau_NFW_30points_MC1122_BKGsklearn.pkl
# mumu_NFW_30points_MC1122_BKGsklearn.pkl
# nuenue_NFW_30points_MC1122_BKGsklearn.pkl
# numunumu_NFW_30points_MC1122_BKGsklearn.pkl
# nutaunutau_NFW_30points_MC1122_BKGsklearn.pkl
# Text(0.5, 1.0, 'NFW')

# %%
profile = 'NFW'
for ch in channels:
    path = [file[i] for i in range(len(file)) if (ch +"_"+ profile in file[i] and '30points_MC1122_BKGFFT' in file[i])]
    if len(path)==0: continue
    print(path[0])
    UL = pkl.load(open(filepath+path[0], "rb"))
    if ch=='bb':
        plt.plot(UL['mass'][1:-1], UL['UL'][1:-1], label=ch_title[ch], color=cols[ch])
    else:    
        plt.plot(UL['mass'], UL['UL'],label=ch_title[ch], color=cols[ch])        

# UL = pkl.load(open('/data/user/tchau/Sandbox/GC_OscNext/Sensitivity/UpperLimit/WW_NFW_10_testv1.pkl', "rb"))
# plt.plot(UL['mass'], UL['UL'], marker='o',label='WW-new', color='gray')    

plt.semilogy()
plt.semilogx()
plt.ylim(1e-25, 6e-22)
plt.legend(ncol=4)
plt.ylabel(r'$\langle \sigma v \rangle$'+r' $[cm^3 s^{-1}]$')
plt.xlabel(r'$m_{\lambda}$'+' [GeV]')
plt.grid()
plt.title('{}'.format(profile))

profile = 'NFW'
for ch in channels:
    path = [file[i] for i in range(len(file)) if (ch +"_"+ profile in file[i] and '30points_MC1122_BKGsklearn' in file[i])]
    if len(path)==0: continue
    print(path[0])
    UL = pkl.load(open(filepath+path[0], "rb"))
    if ch=='bb':
        plt.plot(UL['mass'][1:-1], UL['UL'][1:-1], marker='+', label=ch_title[ch], color=cols[ch])
    else:    
        plt.plot(UL['mass'], UL['UL'], marker='+',label=ch_title[ch], color=cols[ch])        

# UL = pkl.load(open('/data/user/tchau/Sandbox/GC_OscNext/Sensitivity/UpperLimit/WW_NFW_10_testv1.pkl', "rb"))
# plt.plot(UL['mass'], UL['UL'], marker='o',label='WW-new', color='gray')    

plt.semilogy()
plt.semilogx()
plt.ylim(1e-25, 6e-22)
plt.legend(ncol=4)
plt.ylabel(r'$\langle \sigma v \rangle$'+r' $[cm^3 s^{-1}]$')
plt.xlabel(r'$m_{\lambda}$'+' [GeV]')
plt.grid()
plt.title('{}'.format(profile))
# Out:
# WW_NFW_30points_MC1122_BKGFFT.pkl
# bb_NFW_30points_MC1122_BKGFFT.pkl
# tautau_NFW_30points_MC1122_BKGFFT.pkl
# mumu_NFW_30points_MC1122_BKGFFT.pkl
# nuenue_NFW_30points_MC1122_BKGFFT.pkl
# numunumu_NFW_30points_MC1122_BKGFFT.pkl
# nutaunutau_NFW_30points_MC1122_BKGFFT.pkl
# WW_NFW_30points_MC1122_BKGsklearn.pkl
# bb_NFW_30points_MC1122_BKGsklearn.pkl
# tautau_NFW_30points_MC1122_BKGsklearn.pkl
# mumu_NFW_30points_MC1122_BKGsklearn.pkl
# nuenue_NFW_30points_MC1122_BKGsklearn.pkl
# numunumu_NFW_30points_MC1122_BKGsklearn.pkl
# nutaunutau_NFW_30points_MC1122_BKGsklearn.pkl
# Text(0.5, 1.0, 'NFW')
