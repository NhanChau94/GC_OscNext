# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
import numpy as np
from scipy.stats import chi2

sys.path.append("/data/user/tchau/Sandbox/GC_OscNext/PDFs")
sys.path.append("/data/user/tchau/Sandbox/GC_OscNext/DetResponse")
sys.path.append("/data/user/tchau/Sandbox/GC_OscNext/Utils")
from Plot_Histogram import *
from Detector import *
from Background import *
from Signal import *
plt.rcParams['figure.dpi']= 400
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Bin = Std_Binning(1000, N_Etrue=100)
Bkg_bwISJ = ScrambleBkg(Bin, bw="ISJ", oversample=10)
# Out:
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2012_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2013_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2014_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2015_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2016_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2017_pass2_variables_NoCut.pkl
#
# Loading file:
# ...

# %%
plot_projections(Bkg_bwISJ/np.sum(Bkg_bwISJ), np.array([Bin['reco_psi_edges'], np.log10(Bin['reco_energy_edges'])]), r"$\psi_{reco}$", r"$log_{10}(E_{reco})$", "RA Scramble Bkg")
# Out:
# /tmp/ipykernel_11240/220804240.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   plot_projections(Bkg_bwISJ/np.sum(Bkg_bwISJ), np.array([Bin['reco_psi_edges'], np.log10(Bin['reco_energy_edges'])]), r"$\psi_{reco}$", r"$log_{10}(E_{reco})$", "RA Scramble Bkg")

# %%
Bkg_sklearn = ScrambleBkg(Bin, bw=0.03, method='sklearn' ,oversample=10)
# Out:
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2012_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2013_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2014_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2015_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2016_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2017_pass2_variables_NoCut.pkl
#
# Loading file:
# ...

# %%
plot_projections(Bkg_sklearn/np.sum(Bkg_sklearn), np.array([Bin['reco_psi_edges'], np.log10(Bin['reco_energy_edges'])]), r"$\psi_{reco}$", r"$log_{10}(E_{reco})$", "RA Scramble Bkg")
# Out:
# /tmp/ipykernel_23065/4291822129.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   plot_projections(Bkg_sklearn/np.sum(Bkg_sklearn), np.array([Bin['reco_psi_edges'], np.log10(Bin['reco_energy_edges'])]), r"$\psi_{reco}$", r"$log_{10}(E_{reco})$", "RA Scramble Bkg")

# %%
plot_projections(((Bkg_sklearn/np.sum(Bkg_sklearn))-(Bkg_bwISJ/np.sum(Bkg_bwISJ))), np.array([Bin['reco_psi_edges'], np.log10(Bin['reco_energy_edges'])]), r"$\psi_{reco}$", r"$log_{10}(E_{reco})$", "RA Scramble Bkg")
# Out:
# /tmp/ipykernel_23065/1576413803.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   plot_projections(((Bkg_sklearn/np.sum(Bkg_sklearn))-(Bkg_bwISJ/np.sum(Bkg_bwISJ))), np.array([Bin['reco_psi_edges'], np.log10(Bin['reco_energy_edges'])]), r"$\psi_{reco}$", r"$log_{10}(E_{reco})$", "RA Scramble Bkg")

# %%
dat = ScrambleBkg(Bin, kde=False)
# Out:
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2012_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2013_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2014_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2015_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2016_pass2_variables_NoCut.pkl
#
# Loading file:
# /data/user/niovine/projects/DarkMatter_OscNext/Samples/OscNext/L7/Burnsample/OscNext_Level7_v02.00_burnsample_2017_pass2_variables_NoCut.pkl
#
# Loading file:
# ...

# %%
Sklearn_E = (Bkg_sklearn/np.sum(Bkg_sklearn)).sum(axis=0)
FFT_E = (Bkg_bwISJ/np.sum(Bkg_bwISJ)).sum(axis=0)
dat_E = (dat/np.sum(dat)).sum(axis=0)
plt.plot(np.log10(Bin['reco_energy_center']), Sklearn_E, )
plt.plot(np.log10(Bin['reco_energy_center']), FFT_E)
plt.plot(np.log10(Bin['reco_energy_center']), dat_E)

# %%
Sklearn_psi = hist_line((Bkg_sklearn/np.sum(Bkg_sklearn)).sum(axis=1), Bin['reco_psi_edges'])
FFT_psi = hist_line((Bkg_bwISJ/np.sum(Bkg_bwISJ)).sum(axis=1), Bin['reco_psi_edges'])
dat_psi = hist_line((dat/np.sum(dat)).sum(axis=1), Bin['reco_psi_edges'])

plt.plot(Sklearn_psi[0], Sklearn_psi[1], label='sklearn-logpsi-bw0.03')
plt.plot(FFT_psi[0], FFT_psi[1], label='FFT-reflection-bwISJ')
plt.plot(dat_psi[0], dat_psi[1], label='nokde')
plt.title('RA Scramble Bkg')
plt.xlabel(r'$\psi_{reco}$')
plt.semilogy()
plt.legend()
